# %%
import pandas as pd
import numpy as np
import mysql.connector
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
connection = mysql.connector.connect(
    host = os.getenv('DB_HOST'),
    user = os.getenv('DB_USER'),
    password = os.getenv('DB_PASSWORD'),
    database = os.getenv('DB_DATABASE')
)

# %%
df1 = pd.read_csv("./20042023.csv", sep=";")

# %%
df1['data_bloqueio'] = pd.to_datetime(df1['data_bloqueio'], format='%d/%m/%Y %H:%M')
df1['data_arquivo'] = pd.to_datetime(df1['data_arquivo'], format='%d/%m/%Y %H:%M')
df1['data_inicio_bloqueio'] = pd.to_datetime(df1['data_inicio_bloqueio'], format='%d/%m/%Y %H:%M')

# %%
df1['data_bloqueio'] = df1['data_bloqueio'].dt.date
df1['data_arquivo'] = df1['data_arquivo'].dt.date
df1['data_inicio_bloqueio'] = df1['data_inicio_bloqueio'].dt.date

# %%
df1
# Out:
#             origem     telefone data_bloqueio data_arquivo empresa  \
# 0        PROCON AL   8200000000    2021-04-09   2023-04-20   TODAS
# 1        PROCON AL   8201121001    2017-03-03   2023-04-20   TODAS
# 2        PROCON AL   8201234567    2012-10-05   2023-04-20   TODAS
# 3        PROCON AL   8206434118    2019-09-02   2023-04-20   TODAS
# 4        PROCON AL   8208006000    2010-09-16   2023-04-20   TODAS
# ...            ...          ...           ...          ...     ...
# 1048570  PROCON PR  41999188008    2009-09-07   2023-04-20   TODAS
# 1048571  PROCON PR  41999188027    2017-03-08   2023-04-20   TODAS
# 1048572  PROCON PR  41999188044    2019-06-25   2023-04-20   TODAS
# 1048573  PROCON PR  41999188077    2021-07-21   2023-04-20   TODAS
# 1048574  PROCON PR  41999188101    2015-12-04   2023-04-20   TODAS
#
#         data_inicio_bloqueio
# 0                 2021-05-09
# 1                 2017-04-02
# 2                 2012-11-04
# 3                 2019-10-02
# 4                 2010-10-16
# ...                      ...
# 1048570           2009-10-07
# 1048571           2017-04-07
# 1048572           2019-07-25
# 1048573           2021-08-20
# 1048574           2016-01-03
#
# [1048575 rows x 6 columns]

# %%
df = pd.DataFrame(df1)

# %%
df['data_processamento'] = '2023-06-19'

# %%
df
# Out:
#             origem     telefone data_bloqueio data_arquivo empresa  \
# 0        PROCON AL   8200000000    2021-04-09   2023-04-20   TODAS
# 1        PROCON AL   8201121001    2017-03-03   2023-04-20   TODAS
# 2        PROCON AL   8201234567    2012-10-05   2023-04-20   TODAS
# 3        PROCON AL   8206434118    2019-09-02   2023-04-20   TODAS
# 4        PROCON AL   8208006000    2010-09-16   2023-04-20   TODAS
# ...            ...          ...           ...          ...     ...
# 1048570  PROCON PR  41999188008    2009-09-07   2023-04-20   TODAS
# 1048571  PROCON PR  41999188027    2017-03-08   2023-04-20   TODAS
# 1048572  PROCON PR  41999188044    2019-06-25   2023-04-20   TODAS
# 1048573  PROCON PR  41999188077    2021-07-21   2023-04-20   TODAS
# 1048574  PROCON PR  41999188101    2015-12-04   2023-04-20   TODAS
#
#         data_inicio_bloqueio data_processamento
# 0                 2021-05-09         2023-06-19
# 1                 2017-04-02         2023-06-19
# 2                 2012-11-04         2023-06-19
# 3                 2019-10-02         2023-06-19
# 4                 2010-10-16         2023-06-19
# ...                      ...                ...
# 1048570           2009-10-07         2023-06-19
# 1048571           2017-04-07         2023-06-19
# 1048572           2019-07-25         2023-06-19
# 1048573           2021-08-20         2023-06-19
# 1048574           2016-01-03         2023-06-19
#
# [1048575 rows x 7 columns]

# %%
indice = 0
while indice < len(df):
    
    # Obtenha os valores de cada coluna para a linha atual
    origem = df['origem'][indice]
    telefone = df['telefone'][indice]
    data_bloqueio = df['data_bloqueio'][indice]
    data_arquivo = df['data_arquivo'][indice]
    empresa = df['empresa'][indice]
    OrigemPedido = df['data_inicio_bloqueio'][indice]
    data_inicio_bloqueio = df['DATA_PROCESSAMENTO'][indice]

    # Execute a consulta SQL para inserir os dados na tabela
    consulta = "INSERT IGNORE INTO crm_nao_perturbe (origem, telefone, data_bloqueio, data_arquivo, empresa, OrigemPedido, data_inicio_bloqueio) VALUES (%s, %s, %s, %s, %s, %s, %s)"
    valores = (origem, telefone, data_bloqueio, data_arquivo, empresa, OrigemPedido, data_inicio_bloqueio)
    cursor.execute(consulta, valores)

    indice += 1
